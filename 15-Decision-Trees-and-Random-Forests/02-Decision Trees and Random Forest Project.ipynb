# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Random Forest Project
#
# For this project we will be exploring data from [LendingClub.com](www.lendingclub.com). Lending Club connects people who need money (borrowers) with people who have money (investors). Hopefully, as an investor, you would want to invest in people who showed a profile of having a high probability of paying you back. We will try to create a model that will help predict this.
#
# Lending club had a [very interesting year in 2016](https://en.wikipedia.org/wiki/Lending_Club#2016), so let's check out some of their data and keep the context in mind. This data is from before they even went public.
#
# We will use lending data from 2007-2010, and try to predict whether or not the borrower paid back their loan in full. You can download the data from [here](https://www.lendingclub.com/info/download-data.action) or just use the csv already provided. It's recommended you use the csv provided as it has been cleaned of NA values.
#
# Here are what the columns represent:
#
# * **credit.policy**: *Binary* column (1 - the customer meets the credit underwriting criteria of LendingClub.com, 0 - the customer does not meet the credit criteria).
# * **purpose**: The purpose of the loan (allows discrete values "credit_card", "debt_consolidation", "educational", "major_purchase", "small_business", and "all_other").
# * **int.rate**: The interest rate of the loan, as a proportion (a rate of 11% would be stored as 0.11). Borrowers judged by LendingClub.com to be more risky are assigned higher interest rates.
# * **installment**: The monthly installments owed by the borrower if the loan is funded.
# * **log.annual.inc**: The natural log of the self-reported annual income of the borrower.
# * **dti**: The debt-to-income ratio of the borrower (amount of debt divided by annual income).
# * **fico**: The FICO credit score of the borrower.
# * **days.with.cr.line**: The number of days the borrower has had a credit line.
# * **revol.bal**: The borrower's revolving balance (amount unpaid at the end of the credit card billing cycle).
# * **revol.util**: The borrower's revolving line utilization rate (the amount of the credit line used relative to total credit available).
# * **inq.last.6mths**: The borrower's number of inquiries by creditors in the last 6 months.
# * **delinq.2yrs**: The number of times the borrower has been 30+ days late on a payment in the past 2 years.
# * **pub.rec**: The borrower's number of derogatory public records (bankruptcy filings, tax liens, or judgments).
#
# The target column is **not.fully.paid**, which indicates whether loan has been paid or not (0 - fully paid, 1 - not fully paid).

# %% [markdown]
# # Import Libraries
#
# **Import the usual libraries for Pandas and plotting. You can import sklearn later on.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Get the Data
#
# **Use Pandas to read loan_data.csv as a dataframe called loans.**

# %%
loans = pd.read_csv('loan_data.csv')

# %% [markdown]
# **Check out the `info()`, `head()`, and `describe()` methods on loans.**

# %%
# 9578 rows, 14 cols

loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
# Average interest rate is 0.12 with an average of 319 months of installment payments (approx. 26.5 years)
# Average FICO score is approx. 711

# %%
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %% [markdown]
# # Exploratory Data Analysis
#
# We'll use Seaborn and Pandas built-in plotting capabilities, but feel free to use any library you want. Don't worry about the colors matching, just worry about getting the main idea of the plot.
#
# **Create a histogram of two FICO distributions on top of each other, one for each credit.policy outcome.**
#
# *Note: This is pretty tricky, feel free to reference the solutions. You'll probably need one line of code for each histogram, I also recommend just using Pandas built-in `.hist()`*

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))

loans[loans['credit.policy'] == 0]['fico'].hist(bins=30, ax=ax, label='Does not meet credit criteria')
loans[loans['credit.policy'] == 1]['fico'].hist(bins=30, ax=ax, alpha=0.4, label='Meets credit criteria')
plt.xlabel('FICO Credit Score')
plt.legend();

# %%
# Number of clients meeting the credit criteria approx 3.5x greater than those not meeting credit criteria
# Average FICO score for clients who don't meet criteria is around 680, so lower FICO scores tend to not meet requirements 
# (cut-off point is around 660 - any FICO score below does not meet requirements)
# Average FICO score for clients who do meet criteria is around 750

# %% [markdown]
# **Create a similar figure, except this time select by the not.fully.paid column.**

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))

loans[loans['not.fully.paid'] == 0]['fico'].hist(bins=30, ax=ax, alpha=0.4, label='Fully paid')
loans[loans['not.fully.paid'] == 1]['fico'].hist(bins=30, ax=ax, label='Not fully paid')
plt.xlabel('FICO Credit Score')
plt.legend();

# %%
# There are a lot more clients that have fully paid their loans than those who have not (approx. 3.5x more)
# There is similar distribution between those who have fully paid off their loans and those who haven't
# (both distributions have regular spikes, when FICO scores are calculated which causes a larger distribution)

# %% [markdown]
# **Create a countplot using Seaborn showing the counts of loans by purpose, with the color hue defined by not.fully.paid.**

# %%
plt.figure(figsize=(12, 5))

sns.countplot(x='purpose', data=loans, hue='not.fully.paid')
plt.xlabel('PURPOSE OF LOAN');

# %%
# Majority of paid and unpaid loans are for debt consolidation and other purposes
# The ratio between fully paid to not fully paid are roughly the same across all the purposes

# %% [markdown]
# **Let's see the trend between FICO score and interest rate. Recreate the following jointplot.**

# %%
sns.jointplot(x='fico', y='int.rate', data=loans)
plt.xlabel('FICO credit score')
plt.ylabel('Interest Rate');

# %%
# Downward linear trend between interest rate and FICO score 
# - as FICO score increases, customer gets better credit and the interest rate on their loan decreases
# (interest rates have almost bimodal distribution)

# %% [markdown]
# **Create the following 'lmplots' to see if the trend differed between not.fully.paid and credit.policy. Check the documentation for `lmplot()` if you can't figure out how to separate it into columns.**

# %%
sns.lmplot(x='fico', y='int.rate', data=loans, hue='credit.policy', col='not.fully.paid', palette='Set1')
plt.ylabel('Interest Rate')
plt.xlabel('FICO');

# %% [markdown]
# Those who have fully paid off their loans has a greater spread of data with separation around FICO score 660 and an interest rate higher than 0.12 for those who did not meet the credit policy requirements, but overall there are some interest rates as low as 0.06. The majority of those who paid off their loans do meet the credit underwriting criteria.
#
# Those who have not fully paid off their loans show that those who do meet the credit policy and have lower FICO scores have much lower interest rates. Those who do not meet the credit requirements have a clear cut-off point around 660 FICO score, where their interest rate is above 0.12.
#
# The behaviour is basically the same for whether the customer has paid off their loan or not (negative linear trend) AND whether they meet credit underwriting criteria or not. Both variables have a strong influence on the interest rate amount.

# %% [markdown]
# # Setting up the Data
#
# Let's get ready to set up our data for our Random Forest Classification Model.
#
# **Check `loans.info()` again.**

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Categorical Features
#
# Notice that the **purpose** column is categorical with discrete values.
#
# That means we need to transform them using 'dummy' variables so SciKit will be able to understand them. Let's do this in one clean step using `pd.get_dummies`.
#
# Let's show you a way of dealing with these columns that can be expanded to multiple categorical features if necessary.
#
# **Create a list of 1 element containing the string 'purpose'. Call this list cat_feats.**

# %%
cat_feats = ['purpose']

# %% [markdown]
# **Now use `pd.get_dummies(loans, columns=cat_feats, drop_first=True)` to create a fixed larger DataFrame that has new feature columns with 'dummy' variables. Set this DataFrame as final_data.**

# %%
# drop_first=True to avoid multicollinearity

final_data = pd.get_dummies(loans, columns=cat_feats, drop_first=True)

# %%
final_data.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation  \
# ...

# %% [markdown]
# ## Train Test Split
#
# Now its time to split our data into a training set and a testing set.
#
# **Use sklearn to split your data into a training set and a testing set as we've done in the past.**

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_data.drop('not.fully.paid', axis=1)

y = final_data['not.fully.paid']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %% [markdown]
# ## Training a Decision Tree Model
#
# Let's start by training a single decision tree first
#
# **Import DecisionTreeClassifier**

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Create an instance of `DecisionTreeClassifier()` called dtree and fit it to the training data.**

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predictions and Evaluation of Decision Tree
# **Create predictions from the test set and create a classification report and a confusion matrix.**

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83      2386
#            1       0.21      0.22      0.22       488
#
#     accuracy                           0.73      2874
#    macro avg       0.53      0.53      0.53      2874
# weighted avg       0.73      0.73      0.73      2874

# %%
# Accuracy is a bit low, but Precision and Recall are well-balanced

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[1980  406]
#  [ 379  109]]

# %%
# 785 instances were mis-labeled, i.e. incorrect predictions

# %% [markdown]
# ## Training the Random Forest model
#
# Now its time to train our model.
#
# **Create an instance of the RandomForestClassifier class and fit it to our training data from the previous step.**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Choose higher number of trees due to large amount of data

rfc = RandomForestClassifier(n_estimators=300)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %% [markdown]
# ## Predictions and Evaluation
#
# Predict off the y_test values to evaluate our model.
#
# **Predict the class of not.fully.paid for the X_test data.**

# %%
y_pred = rfc.predict(X_test)

# %% [markdown]
# **Create a classification report from the results. Do you get anything strange, or some sort of warning?**

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      2386
#            1       0.50      0.02      0.03       488
#
#     accuracy                           0.83      2874
#    macro avg       0.67      0.51      0.47      2874
# weighted avg       0.78      0.83      0.76      2874

# %%
# Accuracy improved by 10% which is good, with improvements in precision and recall.
# However, target labels are not well-balanced so not a well-balanced sample to work from

# %% [markdown]
# **Show the Confusion Matrix for the predictions.**

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[2378    8]
#  [ 480    8]]

# %%
# 496 instances were mis-labeled, which is much better result (at least 300 more correct predictions)

# %% [markdown]
# **What performed better the random forest or the decision tree?**

# %% [markdown]
# Random Forest Trees outdid the Decision Tree in accuracy but note the Recall score is very low for class 1 labels. Both models need more work, i.e. better feature engineering, maybe feature scaling etc. Random Forest can yield better results than what is shown above. The imbalanced class distribution also needs to be addressed.

# %% [markdown]
# # Great Job!
